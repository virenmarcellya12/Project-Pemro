# %% [markdown]
# <a href="https://colab.research.google.com/github/virenmarcellya12/Project-Pemro/blob/main/Tugas_Kelompok_Minggu_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center> MODEL STASIONER </center></h1><center>Laily Nissa A.Mualifah </center>
#
# <center>
# _____________________________________________________________________________________________________________________________
# </center>

# %% [markdown]
# <h1> Rataan Bergerak (Moving Average) </h1>
#
# Diberikan suatu deret waktu ${Y_t}$, dan deret white noise yang tidak teramati ${e_t}$, yaitu barisan peubah acak yang saling bebas dan memiliki sebaran identik dengan nilai tengah nol.
#
# Proses rataan bergerak (moving average) secara umum atau MA (q) dapat dinyatakan dalam model sebagai berikut:
#
# <center> $Y_t=e_t-\theta_1 e_{t-1}-\theta_2 e_{t-2}-...-\theta_q e_{t-q}$</center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## MA (1)
#
# Proses MA(1) memiliki persamaan:
#
# <center> $Y_t=e_t-\theta e_{t-1}$ </center>
#
# Kita akan membuat simulasi proses MA(1) dengan $\theta=-0.9$.

# %%
np.random.seed(1302)
ar1 = np.array([1])
ma1 = np.array([1, 0.9]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli -0.9 dalam sintaks ditulis 0.9
ma_object1 = ArmaProcess(ar1,ma1)
ma1 = ma_object1.generate_sample(nsample=120)

# %%
plt.figure()
plt.plot(ma1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Bagaimana interpretasi Anda mengenai plot di atas?

# %% [markdown]
# Untuk melihat apakah terdapat hubungan dalam deret antar waktu kita lihat dari plot pencar data berpasangan.

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Apa interpretasi Anda?

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Bagaimana interpretasi Anda dari plot-plot di atas?

# %% [markdown]
# Selain menggunakan plot pencar data berpasangan nilai autokorelasi dapat kita lihat menggunaka **plot ACF (*Autocorelation Function*) contoh**. Plot ACF contoh dapat kita gunakan untuk menentukan ordo dari proses MA.

# %%
plot_acf(ma1, zero=False)
plt.show()

# %% [markdown]
# Bagaimana interpretasi plot ACF di atas?

# %% [markdown]
# Contoh lain untuk simulasikan deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=0.7$.

# %%
np.random.seed(1302)
theta=0.7
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(120):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Apa insight yang Anda peroleh?

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Bagaimana interpretasi Anda?

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# Apa makna dari plot ACF di atas?

# %% [markdown]
# Berdasarkan simulasi di atas apa yang dapat Anda simpulkan tentang nilai autokorelasi pada deret MA(1) berdasarkan plot pencar dan plot ACF?

# %% [markdown]
# ## MA (2)
#
# Proses MA (2) memiliki persamaan:
#
# <center> $Y_t=e_t-\theta_1 e_{t-1}-\theta_2 e_{t-2}$ </center>
#
# Kita akan simulasikan proses MA (2) dengan $\theta_1=1$ dan $\theta_2=-0.6$

# %%
np.random.seed(223)
ar1 = np.array([1])
ma1 = np.array([1, -1, 0.6]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2 = ArmaProcess(ar1,ma1)
ma2 = ma_object2.generate_sample(nsample=120)

# %%
plt.figure()
plt.plot(ma2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Bagaimana interpretasi Anda dari plot-plot di atas?

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Apa insight yang Anda peroleh dari plot-plot di atas?

# %%
plot_acf(ma2, zero=False)
plt.show()

# %% [markdown]
# Bagaimana interpretasi plot ACF di atas?

# %% [markdown]
# Contoh deret simulasi lain untuk MA (2) kita lakukan secara manual berdasarkan persamaan proses MA (2) dengan $\theta_1=-0.5$ dan $\theta_2=-0.7$.

# %%
np.random.seed(1)
theta1, theta2=-0.5, -0.7
ma2_m=[]
et=[np.random.normal(0,1),np.random.normal(0,1)]
for i in range(120):
    et.append(np.random.normal(0,1))
    ma2_m.append(et[i+2]-theta1*et[i+1]-theta2*et[i])

# %%
plt.figure()
plt.plot(ma2_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=4, c='k')
plt.xlabel(r'$Y_{t-4}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma2_m), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan plot-plot di atas apa yang dapat Anda simpulkan tentang nilai autokorelasi pada deret MA(2)?

# %% [markdown]
# <h1> Regresi Diri (Autoregressive) </h1>
#
# Secara spesifik, proses autoregressive order p dari deret ${Y_t}$ memenuhi persamaan berikut:
#
# <center> $Y_t=\phi_1 Y_{t-1}+\phi_2 Y_{t-2}+...+\phi_p Y_{t-p}+e_t$ </center>
#
# Nilai $Y_t$ pada waktu sekarang merupakan kombinasi linier dari sebanyak p nilai $Y_t$ pada waktu lampau ditambah $e_t$ yang saling bebas terhadap $Y_{t-1}, Y_{t-2},...$.
#
#
# <h2> AR (1) </h2>
#
# Proses AR (1) memiliki persamaan:
#
# <center> $Y_t=\phi Y_{t-1}+e_t$ </center>
#
# **Syarat kestasioneran untuk deret AR (1) adalah jika dan hanya jika $|\phi|<1$.**
#
# Kita simulasikan deret AR (1) dengan $\phi=0.9$

# %%
np.random.seed(1302)
ar1 = np.array([1,-0.9]) #nilai parameter phi dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma1 = np.array([1])
ar_object1 = ArmaProcess(ar1,ma1)
ar1 = ar_object1.generate_sample(nsample=120)

# %%
plt.figure(figsize=(10,5))
plt.plot(ar1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Bagaimana interpretasi Anda dari plot tersebut?

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1), lag=4, c='k')
plt.xlabel(r'$Y_{t-4}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Bagaimana perbedaan plot pencar pada model AR dengan MA?

# %%
plot_acf(ar1, zero=False)
plt.show()

# %% [markdown]
# Dari plot ACF contoh tampak nilai autokorelasi yang cukup tinggi dan signifikan sampai lag 6. Perhatikan bahwa nilai autokorelasi bergantian tanda dari negatif ke positif.
#
# **Karena $|\phi|<1$, nilai fungsi autokorelasi berkurang secara eksponensial seiring dengan meningkatnya jumlah lag k. Jika $0<\phi<1$, semua korelasinya bernilai positif, dan jika $-1<\phi<0$, autokorelasi pada lag 1 bernilai negatif dan tanda untuk autokorelasi yang berurutan bergantian dari positif ke negatif, dengan nilainya berkurang secara eksponensial.**
#
# Berdasarkan sifat tersebut, maka nilai ACF contoh tidak dapat kita gunakan untuk menentukan ordo dari proses AR, sehingga kita butuh alat lain. **PACF (Partial Autocorelation Function) contoh** merupakan salah satu alat yang bisa kita gunakan untuk menentukan ordo dari model AR.

# %%
plot_pacf(ar1, zero=False)
plt.show()

# %% [markdown]
# Apa makna dari plot PACF tersebut?

# %% [markdown]
# Contoh lain deret simulasi untuk AR (1) kita lakukan secara manual berdasarkan persamaan proses AR (1) dengan $\phi=-0.8$.

# %%
np.random.seed(1323)
phi=-0.8
ar1_2=[np.random.uniform(0,1)]
for i in range(100):
    ar1_2.append(phi*ar1_2[i]+np.random.normal(0,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(ar1_2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_2), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ar1_2), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar1_2), zero=False)
plt.show()

# %% [markdown]
# Plot PACF contoh menyarankan model AR (1) untuk deret.
#
# <h2> AR (2) </h2>
#
# Proses AR (2) memiliki persamaan:
#
# <center> $Y_t=\phi_1 Y_{t-1}+\phi_2 Y_{t-2}+e_t$ </center>
#
# **Syarat kestasioneran untuk deret AR (2) adalah jika dan hanya jika tiga kondisi berikut terpenuhi, yaitu:**
#
# **<center> $\phi_1+\phi_2<1$  ,   $\phi_2-\phi_1<1$ ,   $|\phi_2|<1$ </center>**
#
# Kita simulasikan deret AR (2) dengan $\phi_1=1.5$ dan $\phi_2=-0.75$

# %%
np.random.seed(1)
psi1, psi2=1.5,-0.75
ar2=[np.random.uniform(0,1),np.random.uniform(0,1)]
for i in range(130):
    ar2.append(psi1*ar2[i+1]+psi2*ar2[i]+np.random.normal(0,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(ar2), zero=False)
plt.show()

# %% [markdown]
# Perhatikan pola ACF tersebut. Apa kaitan pola yang terbentuk dengan sifat dari proses AR?

# %%
plot_pacf(np.array(ar2), zero=False)
plt.show()

# %% [markdown]
# Simulasi deret AR(2) lainnya dengan parameter $\phi_1=0.5$ dan $\phi_2=0.4$

# %%
np.random.seed(1302)
phi1_ar2, phi2_ar2 = 0.5, 0.4

ar_params = np.array([1, -phi1_ar2, -phi2_ar2]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_params = np.array([1])

ar_object2 = ArmaProcess(ar_params, ma_params)
ar2_s = ar_object2.generate_sample(nsample=120)

plt.figure(figsize=(10,5))
plt.plot(ar2_s,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.title(f'Simulasi Data AR(2)')
plt.show()

# %%
plot_acf(np.array(ar2_s), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar2_s), zero=False)
plt.show()

# %% [markdown]
# Perhatikan plot ACF dan PACF dari dua deret simulasi yang mengikuti proses AR(2). Plot ACF dan PACF kedua deret memiliki pola yang berbeda. Apa kaitan perbedaan pola ACF dan PACF dengan sifat dari proses AR(2)?

# %% [markdown]
# <h1> Model Campuran ARMA </h1>
#
# Jika diasumsikan bahwa deret terdiri dari setengah autoregressive dan setengah lagi rataan bergerak, akan diperoleh model deret waktu yang cukup umum dengan persamaan:
#
# <center> $Y_t=\phi_1 Y_{t-1}+\phi_2 Y_{t-2}+...+\phi_p Y_{t-p}+e_t-\theta_1 e_{t-1}-\theta_2 e_{t-2}-...-\theta_q e_{t-q}$ </center>
#
# Dikatakan bahwa $ {Y_t} $merupakan proses campuran autoregressive moving average ordo p dan q, atau disingkat dengan ARMA(p,q).
#
# <h2> ARMA (1,1) </h2>
#
# Persamaan umum untuk proses ARMA (1,1) adalah:
#
# <center> $Y_t=\phi Y_{t-1}+e_t-\theta e_{t-1}$ </center>
#
# Kita simulasikan deret ARMA (1,1) dengan $\phi=0.6$ dan $\theta=-0.3$

# %%
np.random.seed(2026)
ar1 = np.array([1,-0.6]) #nilai parameter phi dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma1 = np.array([1,0.3]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
arma_object1 = ArmaProcess(ar1,ma1)
arma1 = arma_object1.generate_sample(nsample=100)

# %%
plt.figure(figsize=(10,5))
plt.plot(arma1,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Bagaimana pola dari deret tersebut?

# %%
plot_acf(arma1, zero=False)
plt.show()

# %%
plot_pacf(arma1, zero=False)
plt.show()

# %% [markdown]
# Berdasarkan plot ACF contoh contoh terlihat bahwa model yang disarankan adalah MA (2), hal ini tentu tidak sesuai dengan spesifikasi awal deret, dimana untuk komponen rataan bergerak kita definisikan proses MA (1). Sementara dari plot PACF contoh model yang disarankan adalah AR (1). Sehingga model yang sesuai berdasarkan plot ACF dan PACF contoh adalah model AR (1) atau MA (2), dimana seharusnya model yang digunakan adalah ARMA (1,1). Hal ini bisa saja terjadi, sehingga dalam pemodelan deret waktu biasanya digunakan beberapa model tentatif dengan melakukan *overfitting* atau *underfitting* dari model yang disarankan oleh ACF dan PACF.
#
# Kita simulasikan deret ARMA (1,1) yang lainnya secara manual berdasarkan persamaan proses ARMA (1,1) dengan $\phi=0.75$ dan $\theta=0.4$

# %%
np.random.seed(213)
psi1, tetha1=0.75,0.4
et=[np.random.uniform(0,1)]
arma11=[np.random.uniform(0,1)]
for i in range(120):
    et.append(np.random.uniform(0,1))
    arma11.append(psi1*arma11[i]+et[i+1]-tetha1*et[i])

arma11=arma11[21:]

# %%
plt.figure(figsize=(10,5))
plt.plot(arma11,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(arma11), zero=False)
plt.show()

# %%
plot_pacf(np.array(arma11), zero=False)
plt.show()

# %% [markdown]
# Perhatikan plot ACF dan PACF contoh di atas, apa interpretasi Anda?

# %% [markdown]
# <h2> TUGAS KELOMPOK </h2>
#
# Masing-masing kelompok gunakan set.seed jumlah 2 digit terakhir NIM semua anggota kelompok.
#
# 1. Buatlah simulasi deret MA (1) dengan panjang pengamatan 20 dengan nilai parameter $\theta=0.1, \theta=0.3, \theta=0.7, \theta=1.0, \theta=1.5, \theta=2.0$
#
# 2. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 1 dan bandingkan. Berdasarkan plot ACF tersebut, apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA, kaitkan nilai autokorelasi sampel dengan nilai autokorelasi MA(1) secara teori.)
#
# 3. Buatlah simulasi deret MA (1) dengan parameter $\theta=0.25$ dengan panjang pengamatan 60, 100,150, 300.
#
# 4. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 3 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola interval kepercayaan dari nilai autokorelasi berdasarkan panjang observasi.)
#
# 5. Buatlah simulasi deret MA (2) dengan panjang pengamatan 50 dengan parameter:
#
#    a. $\theta_1=0.3, \theta_2=0.8$
#
#    b. $\theta_1=-0.3, \theta_2=0.8$
#
#    c. $\theta_1=0.3, \theta_2=-0.8$
#
#    d. $\theta_1=-0.3, \theta_2=-0.8$
#
# 6. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 5 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 dan 2 dari deret MA(2)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA.)
#
# 7. Buatlah simulasi deret AR (1) 100 pengamatan dengan nilai parameter $\phi=0.3, \phi=0.9, \phi=-0.3, \phi=-0.9$
#
# 8. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 7 dan bandingkan. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(1)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)
#
# 9. Berdasarkan plot ACF dan PACF pada nomor 8, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.
#
# 10. Buatlah simulasi deret AR (2) dengan panjang pengamatan 100 dengan parameter:
#
#    a. $\phi_1=1.5, \phi_2=-0.5$
#
#    b. $\phi_1=0.75, \phi_2=-0.25$
#
#    c. $\phi_1=1, \phi_2=-0.25$
#
#    d. $\phi_1=0.5, \phi_2=-0.75$
#
# 11. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 10. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(2)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)
#
# 12. Berdasarkan plot ACF dan PACF pada nomor 11, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.

# %% [markdown]
# **PENYELESAIAN**

# %% [markdown]
# # MA(1)

# %% [markdown]
# $\theta=0.1$

# %%
np.random.seed(11+44+47)
theta=0.1
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# $\theta=0.3$

# %%
np.random.seed(11+44+47)
theta=0.3
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# $\theta=0.7$

# %%
np.random.seed(11+44+47)
theta=0.7
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# $\theta=1.0$

# %%
np.random.seed(11+44+47)
theta=1.0
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# $\theta=1.5$

# %%
np.random.seed(11+44+47)
theta=1.5
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# $\theta=2.0$

# %%
np.random.seed(11+44+47)
theta=2.0
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# MA (1) dengan parameter $\theta=0.25$  dengan panjang pengamatan 60

# %%
np.random.seed(11+44+47)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(60):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# MA (1) dengan parameter  $\theta=0.25$  dengan panjang pengamatan 100

# %%
np.random.seed(11+44+47)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(100):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# MA (1) dengan parameter  $\theta=0.25$  dengan panjang pengamatan 150

# %%
np.random.seed(11+44+47)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(150):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# MA (1) dengan parameter $\theta=0.25$ dengan panjang pengamatan 300

# %%
np.random.seed(11+44+47)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m=[]
for i in range(300):
    et.append(np.random.normal(0,1))
    ma1_m.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m), zero=False)
plt.show()

# %% [markdown]
# # MA(2)

# %% [markdown]
# $\theta_1$ = 0.3, $\theta_2$ = 0.8

# %%
np.random.seed(11+44+47)

theta1, theta2 = 0.3, 0.8

ma2_1 = []
et = [np.random.normal(0,1), np.random.normal(0,1)]

for i in range(50):
    et.append(np.random.normal(0,1))
    ma2_1.append(et[i+2] - theta1*et[i+1] - theta2*et[i])

# %%
plt.figure()
plt.plot(ma2_1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma2_1), zero=False)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_values, confint = acf(ma2_1, alpha=0.05)

print("Lag | ACF | Lower | Upper")
for lag in range(len(acf_values)):
    print(f"{lag:3d} | {acf_values[lag]:.4f} | {confint[lag,0]:.4f} | {confint[lag,1]:.4f}")
# Out:
# Lag | ACF | Lower | Upper
#   0 | 1.0000 | 1.0000 | 1.0000
#   1 | -0.0560 | -0.3332 | 0.2211
#   2 | -0.5158 | -0.7939 | -0.2378
#   3 | -0.0912 | -0.4350 | 0.2526
#   4 | 0.1812 | -0.1644 | 0.5269
#   5 | 0.1841 | -0.1688 | 0.5370
#   6 | -0.0865 | -0.4467 | 0.2736
#   7 | -0.0781 | -0.4399 | 0.2837
#   8 | -0.1506 | -0.5137 | 0.2125
#   9 | 0.1475 | -0.2204 | 0.5153
#  10 | 0.1347 | -0.2376 | 0.5071
#  11 | -0.3219 | -0.6980 | 0.0541
#  12 | 0.0714 | -0.3253 | 0.4681
#  13 | 0.3516 | -0.0461 | 0.7493
#  14 | -0.0882 | -0.5091 | 0.3327
#  15 | -0.2776 | -0.6999 | 0.1447
#  16 | -0.0177 | -0.4538 | 0.4184

# %%
acf_values, confint = acf(ma2_1, alpha=0.05)

print("ACF lag 2     :", acf_values[2])
print("Lower bound   :", confint[2, 0])
print("Upper bound   :", confint[2, 1])
# Out:
# ACF lag 2     : -0.5158178381734128
# Lower bound   : -0.793867587608766
# Upper bound   : -0.2377680887380595

# %% [markdown]
# $\theta_1$ = -0.3, $\theta_2$ = 0.8

# %%
np.random.seed(11+44+47)

theta1, theta2 = -0.3, 0.8

ma2_2 = []
et = [np.random.normal(0,1), np.random.normal(0,1)]

for i in range(50):
    et.append(np.random.normal(0,1))
    ma2_2.append(et[i+2] - theta1*et[i+1] - theta2*et[i])

# %%
plt.figure()
plt.plot(ma2_2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma2_2), zero=False)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_values, confint = acf(ma2_2, alpha=0.05)

print("Lag | ACF | Lower | Upper")
for lag in range(len(acf_values)):
    print(f"{lag:3d} | {acf_values[lag]:.4f} | {confint[lag,0]:.4f} | {confint[lag,1]:.4f}")
# Out:
# Lag | ACF | Lower | Upper
#   0 | 1.0000 | 1.0000 | 1.0000
#   1 | -0.0043 | -0.2815 | 0.2729
#   2 | -0.5401 | -0.8172 | -0.2629
#   3 | -0.1010 | -0.4498 | 0.2478
#   4 | 0.1765 | -0.1745 | 0.5275
#   5 | 0.1961 | -0.1617 | 0.5539
#   6 | -0.0756 | -0.4415 | 0.2903
#   7 | -0.0843 | -0.4514 | 0.2828
#   8 | -0.1389 | -0.5075 | 0.2297
#   9 | 0.1620 | -0.2106 | 0.5346
#  10 | 0.1201 | -0.2579 | 0.4981
#  11 | -0.3145 | -0.6954 | 0.0664
#  12 | 0.0888 | -0.3116 | 0.4891
#  13 | 0.3684 | -0.0335 | 0.7703
#  14 | -0.0692 | -0.4963 | 0.3578
#  15 | -0.2979 | -0.7258 | 0.1300
#  16 | -0.0098 | -0.4533 | 0.4338

# %%
acf_values, confint = acf(ma2_2, alpha=0.05)

print("ACF lag 2     :", acf_values[2])
print("Lower bound   :", confint[2, 0])
print("Upper bound   :", confint[2, 1])
# Out:
# ACF lag 2     : -0.5400526425987137
# Lower bound   : -0.8172385838151819
# Upper bound   : -0.2628667013822455

# %% [markdown]
# $\theta_1$ = 0.3, $\theta_2$ = -0.8

# %%
np.random.seed(11+44+47)

theta1, theta2 = 0.3, -0.8

ma2_3 = []
et = [np.random.normal(0,1), np.random.normal(0,1)]

for i in range(50):
    et.append(np.random.normal(0,1))
    ma2_3.append(et[i+2] - theta1*et[i+1] - theta2*et[i])

# %%
plt.figure()
plt.plot(ma2_3)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_3), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_3), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma2_3), zero=False)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_values, confint = acf(ma2_3, alpha=0.05)

print("Lag | ACF | Lower | Upper")
for lag in range(len(acf_values)):
    print(f"{lag:3d} | {acf_values[lag]:.4f} | {confint[lag,0]:.4f} | {confint[lag,1]:.4f}")
# Out:
# Lag | ACF | Lower | Upper
#   0 | 1.0000 | 1.0000 | 1.0000
#   1 | -0.5317 | -0.8089 | -0.2546
#   2 | 0.5298 | 0.1829 | 0.8766
#   3 | -0.1609 | -0.5651 | 0.2434
#   4 | 0.0388 | -0.3703 | 0.4479
#   5 | 0.0541 | -0.3553 | 0.4635
#   6 | -0.1940 | -0.6040 | 0.2159
#   7 | 0.1590 | -0.2579 | 0.5760
#   8 | -0.1954 | -0.6169 | 0.2262
#   9 | 0.0522 | -0.3763 | 0.4806
#  10 | 0.0285 | -0.4004 | 0.4575
#  11 | 0.0032 | -0.4260 | 0.4323
#  12 | -0.0293 | -0.4584 | 0.3999
#  13 | 0.1769 | -0.2523 | 0.6062
#  14 | -0.1467 | -0.5815 | 0.2881
#  15 | 0.1140 | -0.3247 | 0.5526
#  16 | -0.0626 | -0.5035 | 0.3783

# %% [markdown]
# $\theta_1$ = -0.3, $\theta_2$ = -0.8

# %%
np.random.seed(11+44+47)

theta1, theta2 = -0.3, -0.8

ma2_4 = []
et = [np.random.normal(0,1), np.random.normal(0,1)]

for i in range(50):
    et.append(np.random.normal(0,1))
    ma2_4.append(et[i+2] - theta1*et[i+1] - theta2*et[i])

# %%
plt.figure()
plt.plot(ma2_4)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_4), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_4), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma2_4), zero=False)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_values, confint = acf(ma2_4, alpha=0.05)

print("Lag | ACF | Lower | Upper")
for lag in range(len(acf_values)):
    print(f"{lag:3d} | {acf_values[lag]:.4f} | {confint[lag,0]:.4f} | {confint[lag,1]:.4f}")
# Out:
# Lag | ACF | Lower | Upper
#   0 | 1.0000 | 1.0000 | 1.0000
#   1 | 0.0271 | -0.2500 | 0.3043
#   2 | 0.4418 | 0.1644 | 0.7192
#   3 | -0.1291 | -0.4562 | 0.1979
#   4 | 0.0506 | -0.2803 | 0.3815
#   5 | 0.0485 | -0.2830 | 0.3799
#   6 | -0.1478 | -0.4798 | 0.1843
#   7 | -0.0194 | -0.3565 | 0.3176
#   8 | -0.1579 | -0.4950 | 0.1793
#   9 | 0.0044 | -0.3384 | 0.3471
#  10 | 0.0096 | -0.3332 | 0.3523
#  11 | 0.0695 | -0.2733 | 0.4123
#  12 | 0.0615 | -0.2824 | 0.4054
#  13 | 0.1707 | -0.1740 | 0.5155
#  14 | -0.0613 | -0.4125 | 0.2898
#  15 | 0.0495 | -0.3025 | 0.4015
#  16 | -0.0738 | -0.4263 | 0.2787

# %% [markdown]
# # AR(1)

# %% [markdown]
# $\phi_1 = 0.3$

# %%
np.random.seed(11+44+47)
phi=0.3
ar1_1=[np.random.uniform(0,1)]
for i in range(99):
    ar1_1.append(phi*ar1_1[i]+np.random.normal(0,1))
len(ar1_1)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar1_1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_1), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ar1_1), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar1_1), zero=False)
plt.show()

# %% [markdown]
# $\phi_1 = 0.9$

# %%
np.random.seed(11+44+47)
phi=0.9
ar1_2=[np.random.uniform(0,1)]
for i in range(99):
    ar1_2.append(phi*ar1_2[i]+np.random.normal(0,1))
len(ar1_2)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar1_2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_2), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ar1_2), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar1_2), zero=False)
plt.show()

# %% [markdown]
# $\phi_1 = -0.3$

# %%
np.random.seed(11+44+47)
phi=-0.3
ar1_3=[np.random.uniform(0,1)]
for i in range(99):
    ar1_3.append(phi*ar1_3[i]+np.random.normal(0,1))
len(ar1_3)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar1_3)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_3), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_3), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_3), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ar1_3), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar1_3), zero=False)
plt.show()

# %% [markdown]
# $\phi_1 = -0.9$

# %%
np.random.seed(11+44+47)
phi=-0.9
ar1_4=[np.random.uniform(0,1)]
for i in range(99):
    ar1_4.append(phi*ar1_4[i]+np.random.normal(0,1))
len(ar1_4)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar1_4)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_4), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_4), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ar1_4), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ar1_4), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar1_4), zero=False)
plt.show()

# %% [markdown]
# # AR(2)

# %% [markdown]
# $\phi_1 = 1.5,\quad \phi_2 = -0.5$

# %%
np.random.seed(11+44+47)
psi1, psi2=1.5,-0.5
ar2_1=[np.random.uniform(0,1),np.random.uniform(0,1)]
for i in range(98):
    ar2_1.append(psi1*ar2_1[i+1]+psi2*ar2_1[i]+np.random.normal(0,1))
len(ar2_1)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_1,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(ar2_1), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar2_1), zero=False)
plt.show()

# %% [markdown]
# $\phi_1 = 0.75,\quad \phi_2 = -0.25$

# %%
np.random.seed(11+44+47)
psi1, psi2=0.75,-0.25
ar2_2=[np.random.uniform(0,1),np.random.uniform(0,1)]
for i in range(98):
    ar2_2.append(psi1*ar2_2[i+1]+psi2*ar2_2[i]+np.random.normal(0,1))
len(ar2_2)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_2,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(ar2_2), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar2_2), zero=False)
plt.show()

# %% [markdown]
# $\phi_1 = 1,\quad \phi_2 = -0.25$

# %%
np.random.seed(11+44+47)
psi1, psi2=1,-0.25
ar2_3=[np.random.uniform(0,1),np.random.uniform(0,1)]
for i in range(98):
    ar2_3.append(psi1*ar2_3[i+1]+psi2*ar2_3[i]+np.random.normal(0,1))
len(ar2_3)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_3,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(ar2_3), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar2_3), zero=False)
plt.show()

# %% [markdown]
# $\phi_1 = 0.5,\quad \phi_2 = -0.75$

# %%
np.random.seed(11+44+47)
psi1, psi2=0.5,-0.75
ar2_4=[np.random.uniform(0,1),np.random.uniform(0,1)]
for i in range(98):
    ar2_4.append(psi1*ar2_4[i+1]+psi2*ar2_4[i]+np.random.normal(0,1))
len(ar2_4)
# Out:
# 100

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_4,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(ar2_4), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar2_4), zero=False)
plt.show()
